# %%
import pandas as pd
import numpy as np

# %%
df_contratos = pd.read_csv('churn_contracts.csv')
df_contratos.head()
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %% [markdown]
# ###Transformando dados

# %%
df_contratos.describe()
# Out:
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000

# %%
df_contratos.dtypes
# Out:
# customerID           object
# tenure                int64
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %%
df_contratos.iloc[488]
# Out:
# customerID                         4472-LVYGI
# tenure                                      0
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df_contratos['TotalCharges'] = df_contratos['TotalCharges'].replace(' ', 'NaN')
df_contratos.iloc[488]
# Out:
# customerID                         4472-LVYGI
# tenure                                      0
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges                              NaN
# Churn                                      No
# Name: 488, dtype: object

# %%
df_contratos['TotalCharges'] = df_contratos['TotalCharges'].astype(float)
df_contratos.head()
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0           Electronic check           29.85         29.85    No
# 1               Mailed check           56.95       1889.50    No
# 2               Mailed check           53.85        108.15   Yes
# 3  Bank transfer (automatic)           42.30       1840.75    No
# 4           Electronic check           70.70        151.65   Yes

# %%
#Força a conversão de dados / transforma o valor em nulo caso encontre um erro
#df_contratos['TotalCharges'] = pd.to_numeric(df_contratos['TotalCharges'], errors='coerce')

# %%
df_contratos.dtypes
# Out:
# customerID           object
# tenure                int64
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# ###Renomear Colunas

# %%
df_clientes = pd.read_csv('churn_customers.csv')
df_clientes.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_clientes = df_clientes.rename(columns = {'SeniorCitizen': 'Elderly_Person'})
df_clientes.head()
# Out:
#    customerID  gender  Elderly_Person Partner Dependents
# 0  7590-VHVEG  Female               0     Yes         No
# 1  5575-GNVDE    Male               0      No         No
# 2  3668-QPYBK    Male               0      No         No
# 3  7795-CFOCW    Male               0      No         No
# 4  9237-HQITU  Female               0      No         No

# %%
df_clientes.rename(columns = {'Partner': 'Casado(a)'}, inplace = True)
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerID      7043 non-null   object
#  1   gender          7043 non-null   object
#  2   Elderly_Person  7043 non-null   int64
#  3   Casado(a)       7043 non-null   object
#  4   Dependents      7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_clientes.columns = ['ID_Clientes', 'Genero', 'Pessoa_Idosa', 'Casado(a)', 'Dependentes']
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Clientes   7043 non-null   object
#  1   Genero        7043 non-null   object
#  2   Pessoa_Idosa  7043 non-null   int64
#  3   Casado(a)     7043 non-null   object
#  4   Dependentes   7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_servicos = pd.read_csv('churn_services.csv')
df_servicos.head()
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %% [markdown]
# ###Juntando DataFrames

# %%
len(df_clientes)
# Out:
# 7043

# %%
len(df_contratos)
# Out:
# 7043

# %%
len(df_servicos)
# Out:
# 7043

# %%
df_servicos.rename(columns={'customerID':'ID_Clientes'}, inplace = True)
df_servicos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Clientes       7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
df_temp = df_clientes.merge(df_servicos, on=['ID_Clientes'])
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Clientes       7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Pessoa_Idosa      7043 non-null   int64
#  3   Casado(a)         7043 non-null   object
#  4   Dependentes       7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
df_temp.head()
# Out:
#   ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0  7590-VHVEG  Female             0       Yes          No           No
# 1  5575-GNVDE    Male             0        No          No          Yes
# 2  3668-QPYBK    Male             0        No          No          Yes
# 3  7795-CFOCW    Male             0        No          No           No
# 4  9237-HQITU  Female             0        No          No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# ...

# %%
df_churn_temp = df_temp.merge(df_contratos, left_on=['ID_Clientes'], right_on=['customerID'])
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Clientes       7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Pessoa_Idosa      7043 non-null   int64
#  3   Casado(a)         7043 non-null   object
#  4   Dependentes       7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
df_churn = df_clientes.merge(df_servicos, on=['ID_Clientes']).merge(df_contratos, left_on=['ID_Clientes'], right_on=['customerID'])
df_churn.head()
# Out:
#   ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0  7590-VHVEG  Female             0       Yes          No           No
# 1  5575-GNVDE    Male             0        No          No          Yes
# 2  3668-QPYBK    Male             0        No          No          Yes
# 3  7795-CFOCW    Male             0        No          No           No
# 4  9237-HQITU  Female             0        No          No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies  customerID tenure        Contract  \
# ...

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Clientes       7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Pessoa_Idosa      7043 non-null   int64
#  3   Casado(a)         7043 non-null   object
#  4   Dependentes       7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
df_churn.drop(['customerID'], inplace=True, axis=1) #axis = 1 é relacionado a coluna
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Clientes       7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Pessoa_Idosa      7043 non-null   int64
#  3   Casado(a)         7043 non-null   object
#  4   Dependentes       7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ###Detecção de valores ausentes

# %%
df_churn.isna()
# Out:
#       ID_Clientes  Genero  Pessoa_Idosa  Casado(a)  Dependentes  PhoneService  \
# 0           False   False         False      False        False         False
# 1           False   False         False      False        False         False
# 2           False   False         False      False        False         False
# 3           False   False         False      False        False         False
# 4           False   False         False      False        False         False
# ...           ...     ...           ...        ...          ...           ...
# 7038        False   False         False      False        False         False
# 7039        False   False         False      False        False         False
# 7040        False   False         False      False        False         False
# 7041        False   False         False      False        False         False
# 7042        False   False         False      False        False         False
#
# ...

# %%
df_churn.isna().sum()
# Out:
# ID_Clientes          0
# Genero               0
# Pessoa_Idosa         0
# Casado(a)            0
# Dependentes          0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#Pega osregistros que possui valor ausente em uma coluna  
df_churn[df_churn.isna().any(axis=1)]
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 488   4472-LVYGI  Female             0       Yes         Yes           No
# 753   3115-CZMZD    Male             0        No         Yes          Yes
# 936   5709-LVOEQ  Female             0       Yes         Yes          Yes
# 1082  4367-NUYAO    Male             0       Yes         Yes          Yes
# 1340  1371-DWPAZ  Female             0       Yes         Yes           No
# 3331  7644-OMVMY    Male             0       Yes         Yes          Yes
# 3826  3213-VVOLG    Male             0       Yes         Yes          Yes
# 4380  2520-SGTTA  Female             0       Yes         Yes          Yes
# 5218  2923-ARZLG    Male             0       Yes         Yes          Yes
# 6670  4075-WKNIU  Female             0       Yes         Yes          Yes
# 6754  2775-SEFEE    Male             0        No         Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# ...

# %%
#Quantas colunsa tem pelo menos um valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ###Tratar os valores ausentes

# %%
#Remover coluna com valor ausente
df_churn.dropna(axis=1)
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
#Remover coluna se todos os valores são ausentes
df_churn.dropna(axis=1, how='all')
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
#Remover linhas com valores ausentes
df_churn.dropna(axis=0)
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
#Remover linhas com todos os valores ausentes
df_churn.dropna(axis=0, how='all')
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ###Inputação de valores ausentes

# %%
#Preenche todos os valores ausentes por 0
df_churn.fillna(0)
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn.fillna(value={'TotalCharges':0})
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_churn.fillna(value={'TotalCharges': df_churn['TotalCharges'].mean()})
# Out:
#      ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0     7590-VHVEG  Female             0       Yes          No           No
# 1     5575-GNVDE    Male             0        No          No          Yes
# 2     3668-QPYBK    Male             0        No          No          Yes
# 3     7795-CFOCW    Male             0        No          No           No
# 4     9237-HQITU  Female             0        No          No          Yes
# ...          ...     ...           ...       ...         ...          ...
# 7038  6840-RESVB    Male             0       Yes         Yes          Yes
# 7039  2234-XADUH  Female             0       Yes         Yes          Yes
# 7040  4801-JZAZL  Female             0       Yes         Yes           No
# 7041  8361-LTMKD    Male             1       Yes          No          Yes
# 7042  3186-AJIEK    Male             0        No          No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ###Dsitribuição variáveis categóricas

# %%
df_churn['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df_churn['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df_churn['Churn'].value_counts(normalize=True) #Valor representado com porcentagem
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df_churn['Churn'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Churn'>

# %%
ax = df_churn['Churn'].value_counts().plot.bar()
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
df_churn['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df_churn['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
ax = df_churn['Contract'].value_counts().plot.bar()
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
df_churn['Genero'].value_counts()
# Out:
# Genero
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
ax = df_churn['Genero'].value_counts().plot.bar()
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3555'), Text(0, 0, '3488')]

# %% [markdown]
# ###Dsitribuição de variável numérica

# %%
df_churn['tenure'].value_counts()
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64

# %%
df_churn['tenure'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [raw]
# A grande concentração dos dados estão nos extremos, seja contratos com poucos meses ou contratos longos, acima 65 meses

# %%
df_churn['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1585, dtype: int64

# %%
df_churn['MonthlyCharges'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_churn['tenure'].mean()
# Out:
# np.float64(32.37114865824223)

# %%
df_churn['tenure'].median()
# Out:
# 29.0

# %%
df_churn['tenure'].mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
df_churn['tenure'].std() #Variação de 24 meses em relação a média
# Out:
# 24.55948102309423

# %%
df_churn['tenure'].std() / df_churn['tenure'].mean() * 100  #Coeficiente de variação
# Out:
# np.float64(75.86842617906603)

# %% [markdown]
# ###Filtros e agrupamento de valores

# %%
#Quais clientes possuem 1 mês de contrato
clinetes_1Mes = df_churn[df_churn['tenure'] == 1]
len(clinetes_1Mes)
# Out:
# 613

# %%
#Representação da informação em porcentagem
len(df_churn[df_churn['tenure'] == 1]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
#Clientes que possuem entre 1 a 5 meses
len(df_churn[(df_churn['tenure'] >= 1) & (df_churn['tenure'] <= 5)]) / len(df_churn) * 100
# Out:
# 19.30995314496663

# %%
len(df_churn[(df_churn['Genero'] == 'Male') & (df_churn['tenure'] <= 5)])
# Out:
# 697

# %%
#Quantidade de clientes por tempo de contrato
df_churn.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
#Representação visual
df_churn.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(figsize=(15,15))
# Out:
# <Axes: ylabel='tenure'>

# %% [markdown]
# ###Tabelas de contigência

# %%
#Tipos de contrato e o Churn
pd.crosstab(df_churn['Churn'], df_churn['Contract'])
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No                  2220      1307      1647
# Yes                 1655       166        48

# %%
pd.crosstab(df_churn['Churn'], df_churn['Contract'], margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
pd.crosstab(df_churn['Churn'], df_churn['Contract'], normalize=True, margins=True, margins_name='Total') * 100
# Out:
# Contract  Month-to-month   One year   Two year       Total
# Churn
# No             31.520659  18.557433  23.384921   73.463013
# Yes            23.498509   2.356950   0.681528   26.536987
# Total          55.019168  20.914383  24.066449  100.000000

# %%
pd.crosstab(df_churn['Churn'], df_churn['Contract'], normalize='index', margins=True, margins_name='Total') * 100
# Out:
# Contract  Month-to-month   One year   Two year
# Churn
# No             42.906842  25.260920  31.832238
# Yes            88.550027   8.881755   2.568218
# Total          55.019168  20.914383  24.066449

# %% [markdown]
# - Do público total, os clientes de contrato mensal representam 85%
# - Dos clientes que abandonaram o serviço, 88% eram de contrato mensal
# - Constata-se que há uma correlação entre contrato mensal e o churn

# %% [markdown]
# ###Teste do Qui-Quadrado
#
# - H0 (hipótese nula): As duas variáveis são independentes.
# - H1 (Hipótese Complementar): As duas variáveis não são independentes
# - No teste, o objetivo é confirmar ou recusar a hipótese nula.
# - Quando o valor de probabilidade H0 for menor que 0.5 (p-value) recusamos a hipótese nula e aceitamos a complementar

# %%
df_tabcont = pd.crosstab(df_churn['Churn'], df_churn['Contract'])

# %%
df_tabcont
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No                  2220      1307      1647
# Yes                 1655       166        48

# %%
from scipy.stats import chi2_contingency

# %%
chi_scores = chi2_contingency(df_tabcont)

# %%
chi_scores
# Out:
# Chi2ContingencyResult(statistic=np.float64(1184.5965720837926), pvalue=np.float64(5.863038300673391e-258), dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
#Número decimal de uma notação cinetífica
pd.set_option('display.float_format', lambda x: '%.15f' % x)

# %%
scores_churn = pd.Series(chi_scores[0])
pvalues_churn = pd.Series(chi_scores[1])

# %%
df_chi_churn = pd.DataFrame({
    'Qui2': scores_churn,
    'PValue': pvalues_churn
})

# %%
df_chi_churn
# Out:
#                   Qui2            PValue
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# As variáveis não são independentes e pelo chi quadrado alto, podemos afirmar que há uma alta correlação entre as variáveis

# %% [markdown]
# ###Correlação entre variáveis (correlação entre variável qualitativa e quantitativa)

# %% [markdown]
# Hipótese: cliente com menos de 6 meses de contrato é mais propenso ao churn

# %%
df_churn['Tempo_menor_6_meses'] = np.where(df_churn['tenure'] < 6, 'Sim', 'Nao')

# %%
df_churn.head(3)
# Out:
#   ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0  7590-VHVEG  Female             0       Yes          No           No
# 1  5575-GNVDE    Male             0        No          No          Yes
# 2  3668-QPYBK    Male             0        No          No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 0          No              No      1  Month-to-month               Yes
# 1          No              No     34        One year                No
# 2          No              No      2  Month-to-month               Yes
#
#       PaymentMethod     MonthlyCharges         TotalCharges  Churn  \
# ...

# %%
df_crosstab_tempo = pd.crosstab(df_churn['Churn'], df_churn['Tempo_menor_6_meses'])

# %%
df_crosstab_tempo
# Out:
# Tempo_menor_6_meses   Nao  Sim
# Churn
# No                   4547  627
# Yes                  1125  744

# %%
chi_scores = chi2_contingency(df_crosstab_tempo)

# %%
chi_scores
# Out:
# Chi2ContingencyResult(statistic=np.float64(669.7216158287102), pvalue=np.float64(1.1485390172689518e-147), dof=1, expected_freq=array([[4166.82209286, 1007.17790714],
#        [1505.17790714,  363.82209286]]))

# %%
scores_churn = pd.Series(chi_scores[0])
pvalues_churn = pd.Series(chi_scores[1])

# %%
df_chi_churn = pd.DataFrame({
    'Qui2': scores_churn,
    'PValue': pvalues_churn
})

# %%
df_chi_churn
# Out:
#                  Qui2            PValue
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# As duas variáveis não são independentes e há uma correlação entre as variáveis, mas não é tão forte quanto a variável tipo de contrato.

# %% [markdown]
# ###Corralação de duas variáveis numéricas

# %%
#Correlação com Pearson. Quanto mais tempo de contrato maior o valor pago
df_churn['tenure'].corr(df_churn['TotalCharges'])
# Out:
# np.float64(0.8258804609332018)

# %%
df_churn['tenure'].corr(df_churn['TotalCharges'], method='spearman')
# Out:
# np.float64(0.8891770805365491)

# %%
df_churn.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# ###Tratando outliers

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_Clientes          7043 non-null   object
#  1   Genero               7043 non-null   object
#  2   Pessoa_Idosa         7043 non-null   int64
#  3   Casado(a)            7043 non-null   object
#  4   Dependentes          7043 non-null   object
#  5   PhoneService         7043 non-null   object
#  6   MultipleLines        7043 non-null   object
#  7   InternetService      7043 non-null   object
#  8   OnlineSecurity       7043 non-null   object
#  9   OnlineBackup         7043 non-null   object
#  10  DeviceProtection     7043 non-null   object
#  11  TechSupport          7043 non-null   object
#  12  StreamingTV          7043 non-null   object
#  13  StreamingMovies      7043 non-null   object
#  14  tenure               7043 non-null   int64
# ...

# %%
df_churn.dropna(axis=0, inplace=True)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_Clientes          7032 non-null   object
#  1   Genero               7032 non-null   object
#  2   Pessoa_Idosa         7032 non-null   int64
#  3   Casado(a)            7032 non-null   object
#  4   Dependentes          7032 non-null   object
#  5   PhoneService         7032 non-null   object
#  6   MultipleLines        7032 non-null   object
#  7   InternetService      7032 non-null   object
#  8   OnlineSecurity       7032 non-null   object
#  9   OnlineBackup         7032 non-null   object
#  10  DeviceProtection     7032 non-null   object
#  11  TechSupport          7032 non-null   object
#  12  StreamingTV          7032 non-null   object
#  13  StreamingMovies      7032 non-null   object
#  14  tenure               7032 non-null   int64
# ...

# %%
df_churn['TotalCharges'].plot.box()
# Out:
# <Axes: >

# %%
df_churn.plot.box(column='TotalCharges', by='Contract')
# Out:
# TotalCharges    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df_churn_month = df_churn[df_churn['Contract'] == 'Month-to-month']

# %%
df_churn_month.head(3)
# Out:
#   ID_Clientes  Genero  Pessoa_Idosa Casado(a) Dependentes PhoneService  \
# 0  7590-VHVEG  Female             0       Yes          No           No
# 2  3668-QPYBK    Male             0        No          No          Yes
# 4  9237-HQITU  Female             0        No          No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 2                No             DSL            Yes          Yes  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 0          No              No      1  Month-to-month               Yes
# 2          No              No      2  Month-to-month               Yes
# 4          No              No      2  Month-to-month               Yes
#
#       PaymentMethod     MonthlyCharges        TotalCharges  Churn  \
# ...

# %%
df_churn_month['TotalCharges'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ###Técnica IQR
#
# - 1° quartil e 3° quartil | 3° quartil - 1° quartil

# %%
q1_total = df_churn_month['TotalCharges'].quantile(0.25)
q3_total = df_churn_month['TotalCharges'].quantile(0.75)

# %%
iqr = q3_total - q1_total
iqr
# Out:
# np.float64(1906.4)

# %%
lim_inf = q1_total - (iqr * 1.5)
lim_sup = q3_total + (iqr * 1.5)

# %%
lim_inf, lim_sup
# Out:
# (np.float64(-2699.5000000000005), np.float64(4926.1))

# %%
len(df_churn_month[(df_churn_month['TotalCharges'] < lim_inf) | (df_churn_month['TotalCharges'] > lim_sup)])
# Out:
# 200

# %% [markdown]
# ###EAD automatizado

# %%
import sweetviz as sv

# %%
sv_churn = sv.analyze(df_churn, target_feat='Churn')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
sv_churn.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
sv_churn.show_html(
    filepath='report.html',
    open_browser = True,
    layout = 'widescreen'
)
# Out:
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Abrindo em uma sessão de navegador existente.
